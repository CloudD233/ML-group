# %%
import pandas as pd

# %%
file_path = "C:/Users/zxckj/Documents/ML-group/fullData.csv"
data = pd.read_csv(file_path)

df = pd.DataFrame(data)

# %%
df
# Out:
#      team_id team_side       date       start_time  doubleheader time_of_day  \
# 0        BAL      Away  3/30/2023  3/30/2023 14:10             0         Day
# 1        BOS      Home  3/30/2023  3/30/2023 14:10             0         Day
# 2        CHC      Home  3/30/2023  3/30/2023 13:20             0         Day
# 3        MIL      Away  3/30/2023  3/30/2023 13:20             0         Day
# 4        CIN      Home  3/30/2023  3/30/2023 16:10             0         Day
# ...      ...       ...        ...              ...           ...         ...
# 4855      SF      Home  10/1/2023  10/1/2023 12:05             0         Day
# 4856     CIN      Away  10/1/2023  10/1/2023 14:15             0         Day
# 4857     STL      Home  10/1/2023  10/1/2023 14:15             0         Day
# 4858      TB      Away  10/1/2023  10/1/2023 15:07             0         Day
# 4859     TOR      Home  10/1/2023  10/1/2023 15:07             0         Day
#
#          sky wind_direction park_id  temperature_fahrenheit  ...  \
# 0      Sunny    LeftToRight   BOS07                      38  ...
# 1      Sunny    LeftToRight   BOS07                      38  ...
# 2      Sunny    RightToLeft   CHI11                      42  ...
# 3      Sunny    RightToLeft   CHI11                      42  ...
# 4      Sunny         FromRf   CIN09                      61  ...
# ...      ...            ...     ...                     ...  ...
# 4855  Cloudy           ToCf   SFO03                      64  ...
# 4856   Sunny    RightToLeft   STL10                      86  ...
# 4857   Sunny    RightToLeft   STL10                      86  ...
# 4858  Cloudy           ToCf   TOR02                      79  ...
# 4859  Cloudy           ToCf   TOR02                      79  ...
#
#       pos6_int_start_distance_h  pos7_int_start_distance_h  \
# 0                           150                        283
# 1                           148                        276
# 2                           147                        293
# 3                           152                        296
# 4                           149                        290
# ...                         ...                        ...
# 4855                        152                        293
# 4856                        148                        307
# 4857                        149                        301
# 4858                        149                        285
# 4859                        147                        299
#
#       pos8_int_start_distance_h pos9_int_start_distance_h  pitcher_run_exp_h  \
# 0                           324                       302               -5.5
# 1                           325                       305               -2.4
# 2                           327                       301                0.6
# 3                           320                       296                4.9
# 4                           325                       303                0.1
# ...                         ...                       ...                ...
# 4855                        318                       300                2.4
# 4856                        322                       307                1.7
# 4857                        327                       308                0.2
# 4858                        313                       281               -5.9
# 4859                        318                       289               -3.1
#
#       run_exp_h  dayOfWeek  duration  runs  scoreLine
# 0           5.5        Thu       190    10  100430200
# 1           2.4        Thu       190     9  100102032
# 2          -0.6        Thu       141     4  00400000x
# 3          -4.9        Thu       141     0  000000000
# 4          -0.1        Thu       182     4  100120000
# ...         ...        ...       ...   ...        ...
# 4855       -2.4        Sun       164     2  000001010
# 4856       -1.7        Sun       136     3  101000100
# 4857       -0.2        Sun       136     4  01300000x
# 4858        5.9        Sun       167    12  170111100
# 4859        3.1        Sun       167     8  030003110
#
# [4860 rows x 79 columns]

# %%
df = df.drop(columns = ['JOIN','field_condition', 'precipitation'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = df.drop(columns = ['JOIN','field_condition', 'precipitation'])
#
# File e:\Anaconda\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File e:\Anaconda\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File e:\Anaconda\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File e:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['JOIN', 'field_condition', 'precipitation'] not found in axis"
